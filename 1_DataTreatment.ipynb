# %%
import glob
import pandas as pd

# %%
a2015=pd.read_csv('2015_Accidentalidad.csv', sep=';')

# %%
a2016=pd.read_csv('2016_Accidentalidad.csv', sep=';')

# %%
a2017=pd.read_csv('2017_Accidentalidad.csv', sep=';')

# %%
a2018=pd.read_csv('2018_Accidentalidad.csv', sep=';')

# %%
accidentes = pd.concat([a2015, a2016, a2017,a2018], sort=True)

# %%
accidentes
# Out:
#        * Nº VICTIMAS CPFA Granizo CPFA Hielo CPFA Lluvia CPFA Niebla  \
# 0                NaN           NO         NO          NO          NO
# 1                NaN           NO         NO          NO          NO
# 2                NaN           NO         NO          NO          NO
# 3                NaN           NO         NO          NO          NO
# 4                NaN           NO         NO          NO          NO
# ...              ...          ...        ...         ...         ...
# 30117            1.0           NO         NO          NO          NO
# 30118            1.0           NO         NO          NO          NO
# 30119            1.0           NO         NO          NO          NO
# 30120            1.0           NO         NO          NO          NO
# 30121            1.0           NO         NO          NO          NO
#
#       CPFA Nieve CPFA Seco CPSV Aceite CPSV Barro CPSV Grava Suelta  ...  \
# ...

# %%
lugar = accidentes['LUGAR ACCIDENTE'].value_counts()

# %%
lugar = pd.DataFrame(lugar)

# %%
lugar
# Out:
#                                                     LUGAR ACCIDENTE
# AUTOVIA  M-30 CALZADA 1 KM.                                    3728
# AUTOVIA  M-30 CALZADA 2 KM.                                    2633
# PASEO DE LA CASTELLANA NUM                     ...             2189
# CALLE DE ALCALA NUM                            ...             1807
# CALLE DE BRAVO MURILLO NUM                     ...              781
# ...                                                             ...
# AUTOVIA  M-40 - AVENIDA DEL ALCALDE CONDE DE MA...                1
# AVENIDA DE ANDALUCIA - CALLE  30  15RA                            1
# CALLE  30  18RA - CUESTA DE SAN VICENTE                           1
# PASEO DEL ESTANQUE                             ...                1
# CAMINO DEL MONTE                               ...                1
#
# [9827 rows x 1 columns]

# %%
distrito = accidentes['DISTRITO'].value_counts()

# %%
distrito = pd.DataFrame(distrito)

# %%
distrito
# Out:
#                                 DISTRITO
# CHAMARTIN                           8834
# SALAMANCA                           8829
# CENTRO                              8089
# CIUDAD LINEAL                       7679
# PUENTE DE VALLECAS                  7668
# CARABANCHEL                         7147
# RETIRO                              6506
# CHAMBERI                            6451
# TETUAN                              6400
# FUENCARRAL-EL PARDO                 6108
# MONCLOA-ARAVACA                     6041
# ARGANZUELA                          5961
# LATINA                              5649
# SAN BLAS                            5598
# HORTALEZA                           4294
# USERA                               4108
# VILLAVERDE                          3137
# MORATALAZ                           2859
# VILLA DE VALLECAS                   2681
# BARAJAS                             1774
# VICALVARO                           1477

# %%
a2019=pd.read_csv('2019_Accidentalidad.csv', sep=';')

# %%
a2020=pd.read_excel('2020_Accidentalidad.xlsx', sep=';')

# %%
a2021=pd.read_excel('2021_Accidentalidad.xlsx', sep=';')

# %%
samur19=pd.read_excel('activaciones_samur_2019.xlsx', sep=';')

# %%
samur20=pd.read_excel('activaciones_samur_2020.xlsx', sep=';')

# %%
samur21=pd.read_excel('activaciones_samur_2021.xlsx', sep=';')

# %%
accidentes = pd.concat([a2019, a2020, a2021], sort=True)

# %%
samur = pd.concat([samur19, samur20, samur21], sort=True)

# %%
accidentes['fecha'] = pd.to_datetime(accidentes['fecha'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-7c2a0b64fb12> in <module>
# ----> 1 accidentes['fecha'] = pd.to_datetime(accidentes['fecha'])
#
# NameError: name 'accidentes' is not defined

# %%
accidentes = accidentes.sort_values(by='fecha')
accidentes
# Out:
#        cod_distrito  cod_lesividad coordenada_x_utm coordenada_y_utm  \
# 795            10.0            NaN      437.103.912    4.471.652.115
# 352             4.0            1.0      442.218.740    4.475.612.690
# 375            15.0            NaN      444.788.493    4.476.802.781
# 732            12.0            NaN      439.824.418    4.470.923.327
# 331            20.0            NaN      447.854.556    4.475.921.794
# ...             ...            ...              ...              ...
# 41696          15.0            NaN      4.43634e+08      4.48137e+09
# 41659           2.0            NaN      4.41143e+08      4.47317e+09
# 41660          17.0            NaN      4.39054e+08      4.46475e+09
# 41662          10.0            NaN       4.3467e+08      4.47041e+09
# 41782           8.0            NaN      4.39875e+08      4.48135e+09
#
#                   distrito estado_meteorológico      fecha      hora  \
# ...

# %%
samur
# Out:
#         Año                         Código       Distrito Hora Intervención  \
# 0      2019           Intoxicación etílica         CENTRO          00:08:15
# 1      2019            Violencia de genero  VALLECAS PTE.               NaN
# 2      2019                          Otros         CENTRO          00:24:22
# 3      2019           Intoxicación etílica         CENTRO               NaN
# 4      2019             Casual: caída, etc         CENTRO          00:34:02
# ...     ...                            ...            ...               ...
# 90136  2021                          Otros    CARABANCHEL          00:06:55
# 90137  2021                        Heridas         CENTRO          23:41:46
# 90138  2021  Accidente menos de 3 victimas    CARABANCHEL          23:43:41
# 90139  2021  Accidente menos de 3 victimas    CARABANCHEL          23:43:41
# 90140  2021         Patología respiratoria         LATINA               NaN
#
#       Hora Solicitud         Hospital         Mes
# ...

# %%
accidentes['tipo_lesividad'].groupby(sum)
# Out:
# array([nan, 'Atención en urgencias sin posterior ingreso',
#        'Asistencia sanitaria sólo en el lugar del accidente',
#        'Sin asistencia sanitaria', 'Ingreso inferior o igual a 24 horas',
#        'Ingreso superior a 24 horas',
#        'Asistencia sanitaria ambulatoria con posterioridad',
#        'Asistencia sanitaria inmediata en centro de salud o mutua',
#        'Se desconoce', 'Fallecido 24 horas'], dtype=object)

# %%
pb = accidentes.groupby(["tipo_lesividad"], as_index=False)['num_expediente'].count()
pb = pb.sort_values(by='num_expediente')
pb
# Out:
#                                       tipo_lesividad  num_expediente
# 7                                       Se desconoce               5
# 4                                 Fallecido 24 horas              68
# 6                        Ingreso superior a 24 horas             947
# 0  Asistencia sanitaria ambulatoria con posterior...            1139
# 3        Atención en urgencias sin posterior ingreso            2226
# 1  Asistencia sanitaria inmediata en centro de sa...            2377
# 5                Ingreso inferior o igual a 24 horas            3467
# 2  Asistencia sanitaria sólo en el lugar del acci...           11459
# 8                           Sin asistencia sanitaria           25985

# %%
accidentes = accidentes[accidentes['tipo_lesividad'] != 'Sin asistencia sanitaria']
accidentes = accidentes[accidentes['tipo_lesividad'] != 'Se desconoce']
accidentes = accidentes[accidentes['tipo_lesividad'] != 'Asistencia sanitaria ambulatoria con posterioridad']

# %%
print(samur.isnull().sum())
# Out:
# Año                       0
# Código                  268
# Distrito               2828
# Hora Intervención     32450
# Hora Solicitud         3804
# Hospital             247512
# Mes                       0
# dtype: int64

# %%
353837-32450
# Out:
# 321387

# %%
accidentes = accidentes.drop(['lesividad', 'positiva_alcohol', 'positiva_droga', 'tipo_vehiculo', 'cod_distrito', 'cod_lesividad'], axis=1)

# %%
accidentes['fecha'] = pd.to_datetime(accidentes['fecha'])

# %%
accidentes = accidentes.sort_values(by='fecha')
accidentes
# Out:
#        cod_distrito  cod_lesividad coordenada_x_utm coordenada_y_utm  \
# 352             4.0            1.0      442.218.740    4.475.612.690
# 52              5.0            2.0      441.926.445    4.480.967.858
# 61              4.0            7.0      441.415.905    4.475.085.246
# 60              4.0            7.0      441.415.905    4.475.085.246
# 59              4.0            7.0      441.415.905    4.475.085.246
# ...             ...            ...              ...              ...
# 32307          20.0            7.0      4.47929e+08      4.47733e+09
# 32243           8.0            6.0      4.39203e+08      4.48024e+09
# 32229          12.0            7.0      4.43286e+08      4.47238e+09
# 32252          16.0            3.0       4.4533e+08      4.48052e+09
# 32298           5.0            7.0      4.41722e+08      4.48044e+09
#
#                   distrito estado_meteorológico      fecha      hora  \
# ...

# %%
accidentes['coordenada_x_utm']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-87b854943aaa> in <module>
# ----> 1 int(accidentes['coordenada_x_utm'])
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in wrapper(self)
#     129         if len(self) == 1:
#     130             return converter(self.iloc[0])
# --> 131         raise TypeError("cannot convert the series to " "{0}".format(str(converter)))
#     132
#     133     wrapper.__name__ = "__{name}__".format(name=converter.__name__)
#
# TypeError: cannot convert the series to <class 'int'>

# %%
print(accidentes.isnull().sum())
# Out:
# cod_distrito            0
# cod_lesividad           0
# coordenada_x_utm        0
# coordenada_y_utm        0
# distrito                0
# estado_meteorológico    0
# fecha                   0
# hora                    0
# localizacion            0
# num_expediente          0
# numero                  0
# rango_edad              0
# sexo                    0
# tipo_accidente          0
# tipo_lesividad          0
# tipo_persona            0
# tipo_vehículo           0
# dtype: int64

# %%
accidentes = accidentes.dropna()
accidentes = accidentes.reset_index()

# %%
accidentes.to_csv('accidentes_limpio.csv', index = False)

# %%
len(samur['Código'].unique())
# Out:
# 93

# %%
#accidentes['positiva_droga'].unique()
accidentes = accidentes[~accidentes["positiva_droga"].isna]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-df7572092f9d> in <module>
#       1 #accidentes['positiva_droga'].unique()
# ----> 2 accidentes = accidentes[~accidentes["positiva_droga"].isna]
#
# TypeError: bad operand type for unary ~: 'method'

# %%
df1=accidentes[~accidentes['positiva_droga'].isna()]
df2=df1[~df1['lesividad'].isna()]
df2
# Out:
#        cod_distrito  cod_lesividad coordenada_x_utm coordenada_y_utm  \
# 994             2.0           14.0      4.40976e+08      4.47173e+09
# 1321           17.0           14.0      4.39028e+08      4.46549e+09
# 2558           15.0           14.0      4.46572e+08      4.47523e+09
# 2874            8.0           14.0      4.40917e+08      4.48229e+09
# 4292           11.0            1.0       4.3835e+08      4.47293e+09
# ...             ...            ...              ...              ...
# 38623           9.0           14.0      4.39509e+08      4.47534e+09
# 39880          20.0           14.0      4.48341e+08      4.47783e+09
# 40434           3.0           14.0      4.42756e+08      4.47438e+09
# 40800          13.0           14.0      4.42798e+08       4.4717e+09
# 40969          13.0           14.0      4.44572e+08       4.4702e+09
#
#                   distrito estado_meteorológico      fecha      hora  \
# ...

# %%
accidentes['tipo_persona'].unique()
# Out:
# array(['Conductor', 'Pasajero', 'Peatón', nan], dtype=object)

# %%
samur=samur.reset_index()

# %%
from datetime import datetime
samur['fecha_int']=0
for i in range(len(samur)):
    if str(samur['Hora Solicitud'][i])=='nan':
        samur['Hora Solicitud'][i]=samur['Hora Solicitud'][i-1]
        fecha1=datetime.strptime(str(samur['Hora Solicitud'][i]), '%H:%M:%S')
        fecha=int(fecha1.strftime('%H%M%S'))
        samur['fecha_int'][i]=fecha
    else:
        fecha1=datetime.strptime(str(samur['Hora Solicitud'][i]), '%H:%M:%S')
        fecha=int(fecha1.strftime('%H%M%S'))
        samur['fecha_int'][i]=fecha
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':

# %%
import datetime
dia = datetime.datetime(2019, 1, 1)
samur['fecha'] = datetime.datetime(2019, 1, 1)
#samur['Dia_3']=dia
for i in range(len(samur)):
    if i>0:
        if samur['fecha_int'][i]<samur['fecha_int'][i-1]:
            dia=dia+datetime.timedelta(days=1)
        samur['fecha'][i]=dia
    else:
        samur['fecha'][i]=dia
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
samur = samur.drop(['fecha_int'], axis=1)

# %%
samur
# Out:
#        index   Año                         Código       Distrito  \
# 0          7  2019       Accidente de motocicleta         RETIRO
# 1          8  2019       Accidente de motocicleta         RETIRO
# 2          9  2019       Accidente de motocicleta         RETIRO
# 3         16  2019       Accidente de motocicleta     FUENCARRAL
# 4         23  2019       Accidente de motocicleta         RETIRO
# ...      ...   ...                            ...            ...
# 36318  90115  2021       Accidente de motocicleta  VALLECAS PTE.
# 36319  90122  2021       Accidente de motocicleta     ARGANZUELA
# 36320  90126  2021         Accidente de bicicleta      SALAMANCA
# 36321  90138  2021  Accidente menos de 3 victimas    CARABANCHEL
# 36322  90139  2021  Accidente menos de 3 victimas    CARABANCHEL
#
#       Hora Intervención Hora Solicitud            Hospital         Mes  \
# 0              00:42:10       00:35:36     Doce de Octubre       ENERO
# ...

# %%
len(samur['Código'].unique())
# Out:
# 9

# %%
lista = ["Accidente de motocicleta", "Accidente menos de 3 victimas", "Atropello", "Accidente de bicicleta", "Accidente con 3 o más víctimas confirmadas", "Accidente sin especificar", "Accidente de autobús / autocar", "Accidente con vehículo pesado", "Acc. Trasp. Merc. Peligrosas"]

# %%
samur = samur[samur.Código.isin(lista)]

# %%
len(samur)
# Out:
# 40187

# %%
samur = samur.dropna()

# %%
samur['Hospital'] = samur['Hospital'].fillna('Sin traslado')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
print(samur.isnull().sum())
# Out:
# Año                     0
# Código                  0
# Distrito              516
# Hora Intervención    3415
# Hora Solicitud        381
# Hospital                0
# Mes                     0
# dtype: int64

# %%
samur
# Out:
#        index   Año                         Código       Distrito  \
# 0          7  2019       Accidente de motocicleta         RETIRO
# 1          8  2019       Accidente de motocicleta         RETIRO
# 2          9  2019       Accidente de motocicleta         RETIRO
# 3         16  2019       Accidente de motocicleta     FUENCARRAL
# 4         23  2019       Accidente de motocicleta         RETIRO
# ...      ...   ...                            ...            ...
# 36318  90115  2021       Accidente de motocicleta  VALLECAS PTE.
# 36319  90122  2021       Accidente de motocicleta     ARGANZUELA
# 36320  90126  2021         Accidente de bicicleta      SALAMANCA
# 36321  90138  2021  Accidente menos de 3 victimas    CARABANCHEL
# 36322  90139  2021  Accidente menos de 3 victimas    CARABANCHEL
#
#       Hora Intervención Hora Solicitud            Hospital         Mes  \
# 0              00:42:10       00:35:36     Doce de Octubre       ENERO
# ...

# %%
import datetime
import numpy as np
import matplotlib.pyplot as plt

# %%
fech = samur.groupby(by=["fecha"]).count()

# %%
pd.DataFrame(fech)
# Out:
#             index
# fecha
# 2019-01-01     32
# 2019-01-02     36
# 2019-01-03     28
# 2019-01-04     45
# 2019-01-05     28
# ...           ...
# 2021-09-26     42
# 2021-09-27     53
# 2021-09-28     35
# 2021-09-29     37
# 2021-09-30     46
#
# [1001 rows x 1 columns]

# %%
plt.plot(fech)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
samur.to_excel('samur.xlsx', sheet_name='samur')

# %%
from datetime import datetime

# %%
samur = pd.read_excel('samur.xlsx')

# %%
prueba.dtypes
# Out:
# index                         int64
# Año                           int64
# Código                       object
# Distrito                     object
# Hora Intervención            object
# Hora Solicitud               object
# Hospital                     object
# Mes                          object
# fecha                datetime64[ns]
# dtype: object

# %%
samur
# Out:
#        index   Año                         Código       Distrito  \
# 0          7  2019       Accidente de motocicleta         RETIRO
# 1          8  2019       Accidente de motocicleta         RETIRO
# 2          9  2019       Accidente de motocicleta         RETIRO
# 3         16  2019       Accidente de motocicleta     FUENCARRAL
# 4         23  2019       Accidente de motocicleta         RETIRO
# ...      ...   ...                            ...            ...
# 36318  90115  2021       Accidente de motocicleta  VALLECAS PTE.
# 36319  90122  2021       Accidente de motocicleta     ARGANZUELA
# 36320  90126  2021         Accidente de bicicleta      SALAMANCA
# 36321  90138  2021  Accidente menos de 3 victimas    CARABANCHEL
# 36322  90139  2021  Accidente menos de 3 victimas    CARABANCHEL
#
#       Hora Intervención Hora Solicitud            Hospital         Mes  \
# 0              00:42:10       00:35:36     Doce de Octubre       ENERO
# ...

# %%
prueba['Hora Solicitud'] = pd.to_datetime(prueba['Hora Solicitud'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-151-8be50a4afb67> in <module>
# ----> 1 prueba['Hora Solicitud'] = pd.to_datetime(prueba['Hora Solicitud'])
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     206                 else:
#     207                     kwargs[new_arg_name] = new_arg_value
# --> 208             return func(*args, **kwargs)
#     209
#     210         return wrapper
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin, cache)
#     776             result = arg.map(cache_array)
#     777         else:
# --> 778             values = convert_listlike(arg._values, True, format)
# ...

# %%
datetime.strptime(samur['Hora Solicitud'][1], '%H:%M:%S')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-149-099c38eaeba8> in <module>
# ----> 1 datetime.strptime(samur['Hora Solicitud'][1], '%H:%M:%S')
#
# TypeError: strptime() argument 1 must be str, not datetime.time

# %%
from datetime import datetime,date
hola = samur['Hora Intervención'][9989] 
adios = samur['Hora Solicitud'][9989]
((datetime.combine(samur['fecha'][9989], hola) - datetime.combine(samur['fecha'][9989], adios)).seconds)/60
# Out:
# 3.066666666666667

# %%
from datetime import datetime,date
samur['Demora'] = datetime.now()

for i in range(len(samur)):
    hola = samur['Hora Intervención'][i] 
    adios = samur['Hora Solicitud'][i]
    samur['Demora'][i] = ((datetime.combine(samur['fecha'][i], hola) - datetime.combine(samur['fecha'][i], adios)).seconds)/60
    
    
    #samur['Hora Solicitud'][i] = (datetime.strptime(samur['Hora Solicitud'][i], '%H:%M:%S').strftime("%H:%M:%S"))
    #prueb = prueba2.strftime("%H:%M:%S")
    #samur['Hora Solicitud'].append(prueb)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
for i in range(len(samur)):
    samur['Demora'][i] = round(samur['Demora'][i], 2)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
samur
# Out:
#        index   Año                         Código       Distrito  \
# 0          7  2019       Accidente de motocicleta         RETIRO
# 1          8  2019       Accidente de motocicleta         RETIRO
# 2          9  2019       Accidente de motocicleta         RETIRO
# 3         16  2019       Accidente de motocicleta     FUENCARRAL
# 4         23  2019       Accidente de motocicleta         RETIRO
# ...      ...   ...                            ...            ...
# 36318  90115  2021       Accidente de motocicleta  VALLECAS PTE.
# 36319  90122  2021       Accidente de motocicleta     ARGANZUELA
# 36320  90126  2021         Accidente de bicicleta      SALAMANCA
# 36321  90138  2021  Accidente menos de 3 victimas    CARABANCHEL
# 36322  90139  2021  Accidente menos de 3 victimas    CARABANCHEL
#
#       Hora Intervención Hora Solicitud            Hospital         Mes  \
# 0              00:42:10       00:35:36     Doce de Octubre       ENERO
# ...
